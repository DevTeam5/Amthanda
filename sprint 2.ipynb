# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dataFrame.csv",sep=";")
df
# Out:
#          Type          Product   Price   Quantity
# 0      Chips              Simba     6.0      25.0
# 1         NaN              Lays     7.0      20.0
# 2         NaN           Doritos     7.0      25.0
# 3         NaN            Fritos     3.0      30.0
# 4         NaN           Cheetos     4.0      40.0
# 5         NaN          Pringles    19.0      15.0
# 6         NaN           NikNaks     3.0      50.0
# 7         NaN               NaN     NaN       NaN
# 8   Chocolate             Flake    11.0      30.0
# 9         NaN               Tex     9.0      25.0
# 10        NaN           KitKat     10.0      20.0
# 11        NaN           Cruchie    12.0      35.0
# 12        NaN              Aero    15.0      15.0
# 13        NaN        Dairy Milk    16.0      15.0
# 14        NaN         Milky bar    14.0      20.0
# 15        NaN               NaN     NaN       NaN
# 16     Drinks         Coca-Cola    15.0      12.0
# 17        NaN             Pepsi    15.0      12.0
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Amthanda@1"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
from matplotlib import pyplot as plt
from matplotlib import style
 
x = ['Simba', 'Lays', 'Doritos', 'Pringles', 'Cheeetos', 'Nik naks', 'Fritos']
y = [6, 7, 7, 19, 4, 3, 3]

plt.bar(x, y, align = 'center')

plt.title('chips')
plt.ylabel('price list of chips in Rands')

plt.show()

# %%
import matplotlib.pyplot as plt 
  
x = ['Flake', 'Tex', 'KitKat', 'Crunchie', 'Aero', 'Dairy Milk', 'Milky bar'] 
y = [11,9,10,12,15,16,14] 
    
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
   
plt.title('Chocolates') 
   
plt.show()

# %%
import matplotlib.pyplot as plt
y = [25, 19, 15, 20, 17]
x = ['Chicken', 'Pepper steak', 'Steak & kidney', 'curried mutton', 'meat & potato']
plt.scatter(x, y)
plt.show()

# %%
y = [25, 20, 24, 19, 10, 15, 18]

plt.hist(y)

plt.xlabel('Drinks')

plt.ylabel('Prices')

plt.show()

# %%
import matplotlib.pyplot as pyplot

x = ['Apple', 'Banana', 'Pear', 'Mango', 'Grapes', 'Peach', 'Orange']
y = [3, 3, 4, 12, 10, 4, 3]

plt.plot(x,y)

pyplot.title('Fruit')

pyplot.xlabel('types of fruits')
pyplot.ylabel('price list of Fruit in Rands')
pyplot.show()
